# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import requests
import time
import timestring
from datetime import datetime

# %%
# fetch the appropriate dataset via API
# city of Chicago
#year = {'year': ['2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']}
year = {'year': ['2013']} # currently doesn't work for multiple years
url = 'https://data.cityofchicago.org/resource/6zsd-86xi.json'
r = requests.get(url, params=year, stream=True)
chicago_df = pd.DataFrame(r.json())

chicago_df.head()
#chicago_df['primary_type'].describe()
#pd.unique(chicago_df['primary_type'].values.ravel())
#chicago_df['primary_type'].value_counts()
chicago_df.describe()
# Out:
#           arrest   domestic
# count       1000       1000
# mean        0.35      0.223
# std    0.4772083  0.4164666
# min        False      False
# 25%            0          0
# 50%            0          0
# 75%            1          0
# max         True       True

# %%
chicago_df = pd.read_csv('crime_chicago.csv')
chicago_df.describe()
# Out:
# /Applications/anaconda_python_2.7/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:1170: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)
#                     ID     Arrest   Domestic            Beat        District  \
# count   5842327.000000    5842327    5842327  5842327.000000  4641096.000000
# mean    5510762.150537  0.2883697  0.1268024     1199.233245       11.303610
# std     2606575.002851   0.453004  0.3327515      704.473403        6.935569
# min         634.000000      False      False      111.000000        1.000000
# 25%     3143175.500000          0          0      623.000000        6.000000
# 50%     5456303.000000          0          0     1111.000000       10.000000
# 75%     7783873.500000          1          0     1732.000000       17.000000
# max    10156579.000000       True       True     2535.000000       31.000000
#
# ...

# %%
# city of Washington DC
washington_df = pd.read_csv('crime_incidents_2013_CSV.csv')
#washington_df.head()
pd.unique(washington_df['OFFENSE'].values.ravel())
washington_df['OFFENSE'].value_counts()
# Out:
# THEFT/OTHER                   12904
# THEFT F/AUTO                  10130
# ROBBERY                        4071
# BURGLARY                       3370
# MOTOR VEHICLE THEFT            2675
# ASSAULT W/DANGEROUS WEAPON     2309
# SEX ABUSE                       299
# HOMICIDE                        104
# ARSON                            35
# dtype: int64
